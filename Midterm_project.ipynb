# %%
# Midterm Starter: Retail Sales (Logistic Regression)
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score
from imblearn.over_sampling import SMOTE

df = pd.read_csv("Midterm_Retail_Sales.csv")
# Drop OrderID as it's not a predictive feature
df = df.drop('OrderID', axis=1)

# Handle categorical variables
categorical_cols = df.select_dtypes(include=['object']).columns
df = pd.get_dummies(df, columns=categorical_cols, drop_first=True)


X = df.drop("Returned", axis=1)
y = df["Returned"]
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=42)

# Apply SMOTE to the training data
smote = SMOTE(random_state=42)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)


clf = LogisticRegression(max_iter=1000)
# Train on the resampled data
clf.fit(X_train_resampled,y_train_resampled)
y_pred = clf.predict(X_test)
print("Accuracy:", accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# Accuracy: 0.8333333333333334
#               precision    recall  f1-score   support
#
#            0       0.83      1.00      0.91        50
#            1       0.00      0.00      0.00        10
#
#     accuracy                           0.83        60
#    macro avg       0.42      0.50      0.45        60
# weighted avg       0.69      0.83      0.76        60
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score
from imblearn.over_sampling import SMOTE

# Assuming X_train, X_test, y_train, y_test are already defined and SMOTE has been applied
# If not, the previous cells for data loading, preprocessing, splitting, and SMOTE need to be run first.

# Re-evaluate Logistic Regression Model
clf = LogisticRegression(max_iter=1000)
# Train on the resampled data
clf.fit(X_train_resampled,y_train_resampled)
y_pred = clf.predict(X_test)


# Re-evaluate Decision Tree Model
# Instantiate the Decision Tree Classifier
dt_clf_resampled = DecisionTreeClassifier(random_state=42)

# Fit the model to the resampled training data
dt_clf_resampled.fit(X_train_resampled, y_train_resampled)

# Make predictions on the original testing data
y_pred_dt_resampled = dt_clf_resampled.predict(X_test)


# Compare Models
print("Logistic Regression Classification Report (with SMOTE):")
print(classification_report(y_test, y_pred))

print("\nDecision Tree Classification Report (with SMOTE):")
print(classification_report(y_test, y_pred_dt_resampled))
# Out:
# Logistic Regression Classification Report (with SMOTE):
#               precision    recall  f1-score   support
#
#            0       0.83      1.00      0.91        50
#            1       0.00      0.00      0.00        10
#
#     accuracy                           0.83        60
#    macro avg       0.42      0.50      0.45        60
# weighted avg       0.69      0.83      0.76        60
#
#
# Decision Tree Classification Report (with SMOTE):
#               precision    recall  f1-score   support
#
#            0       0.83      1.00      0.91        50
#            1       0.00      0.00      0.00        10
#
#     accuracy                           0.83        60
#    macro avg       0.42      0.50      0.45        60
# weighted avg       0.69      0.83      0.76        60
# ...

# %% [markdown]
# ### Compare Models

# %%
from sklearn.tree import DecisionTreeClassifier

# Instantiate the Decision Tree Classifier
dt_clf_resampled = DecisionTreeClassifier(random_state=42)

# Fit the model to the resampled training data
dt_clf_resampled.fit(X_train_resampled, y_train_resampled)

# Make predictions on the original testing data
y_pred_dt_resampled = dt_clf_resampled.predict(X_test)

# Calculate and print the accuracy score
accuracy_dt_resampled = accuracy_score(y_test, y_pred_dt_resampled)
print("Decision Tree Accuracy (with SMOTE):", accuracy_dt_resampled)

# Print the classification report
print("Decision Tree Classification Report (with SMOTE):")
print(classification_report(y_test, y_pred_dt_resampled))
# Out:
# Decision Tree Accuracy (with SMOTE): 0.8333333333333334
# Decision Tree Classification Report (with SMOTE):
#               precision    recall  f1-score   support
#
#            0       0.83      1.00      0.91        50
#            1       0.00      0.00      0.00        10
#
#     accuracy                           0.83        60
#    macro avg       0.42      0.50      0.45        60
# weighted avg       0.69      0.83      0.76        60
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %% [markdown]
# ### Address Class Imbalance using SMOTE

# %%
from imblearn.over_sampling import SMOTE

# Apply SMOTE to the training data
smote = SMOTE(random_state=42)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

print("Shape of original training data:", X_train.shape)
print("Shape of resampled training data:", X_train_resampled.shape)
print("\nValue counts of original target variable:")
print(y_train.value_counts())
print("\nValue counts of resampled target variable:")
print(y_train_resampled.value_counts())
# Out:
# Shape of original training data: (140, 208)
# Shape of resampled training data: (246, 208)
#
# Value counts of original target variable:
# Returned
# 0    123
# 1     17
# Name: count, dtype: int64
#
# Value counts of resampled target variable:
# Returned
# 0    123
# 1    123
# Name: count, dtype: int64

# %%
display(df.head())
# Out:
#    Quantity  UnitPrice  Returned    Sales  OrderDate_2024-01-02  \
# 0         5     219.35         0  1096.75                 False
# 1         3     155.37         0   466.11                  True
# 2         1     124.06         0   124.06                 False
# 3         1     124.29         0   124.29                 False
# 4         1      71.76         1    71.76                 False
#
#    OrderDate_2024-01-03  OrderDate_2024-01-04  OrderDate_2024-01-05  \
# 0                 False                 False                 False
# 1                 False                 False                 False
# 2                  True                 False                 False
# 3                 False                  True                 False
# 4                 False                 False                  True
#
#    OrderDate_2024-01-06  OrderDate_2024-01-07  ...  OrderDate_2024-07-15  \
# 0                 False                 False  ...                 False
# ...

# %% [markdown]
# ## Data preprocessing

# %%
print("Missing values per column:")
print(df.isnull().sum())
categorical_cols = df.select_dtypes(include=['object']).columns
print("\nCategorical columns identified:")
print(categorical_cols)
df = pd.get_dummies(df, columns=categorical_cols, drop_first=True)
display(df.head())
# Out:
# Missing values per column:
# Quantity                0
# UnitPrice               0
# Returned                0
# Sales                   0
# OrderDate_2024-01-02    0
#                        ..
# Region_South            0
# Region_West             0
# Category_Electronics    0
# Category_Grocery        0
# Category_Home           0
# Length: 209, dtype: int64
#
# Categorical columns identified:
# Index([], dtype='object')
#    Quantity  UnitPrice  Returned    Sales  OrderDate_2024-01-02  \
# 0         5     219.35         0  1096.75                 False
# 1         3     155.37         0   466.11                  True
# 2         1     124.06         0   124.06                 False
# 3         1     124.29         0   124.29                 False
# 4         1      71.76         1    71.76                 False
#
#    OrderDate_2024-01-03  OrderDate_2024-01-04  OrderDate_2024-01-05  \
# 0                 False                 False                 False
# ...

# %% [markdown]
# ## Descriptive statistics

# %%
relevant_columns = ['Quantity', 'UnitPrice', 'Sales', 'Returned']
descriptive_stats = df[relevant_columns].describe()
print(descriptive_stats)
# Out:
#          Quantity   UnitPrice       Sales    Returned
# count  200.000000  200.000000   200.00000  200.000000
# mean     3.195000  152.581000   478.87995    0.135000
# std      1.384398   85.321824   345.87948    0.342581
# min      1.000000    5.400000    12.94000    0.000000
# 25%      2.000000   76.845000   184.92250    0.000000
# 50%      3.000000  154.315000   421.84000    0.000000
# 75%      4.000000  233.212500   705.34250    0.000000
# max      5.000000  292.750000  1453.15000    1.000000

# %% [markdown]
# ## Data visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Histogram of 'Quantity'
plt.figure(figsize=(8, 5))
sns.histplot(df['Quantity'], kde=True)
plt.title('Distribution of Quantity')
plt.xlabel('Quantity')
plt.ylabel('Frequency')
plt.show()

# 2. Box plot of 'UnitPrice'
plt.figure(figsize=(8, 5))
sns.boxplot(x=df['UnitPrice'])
plt.title('Box Plot of Unit Price')
plt.xlabel('Unit Price')
plt.ylabel('Value')
plt.show()

# 3. Scatter plot of 'Sales' vs. 'Quantity'
plt.figure(figsize=(8, 5))
sns.scatterplot(x='Quantity', y='Sales', data=df)
plt.title('Sales vs. Quantity')
plt.xlabel('Quantity')
plt.ylabel('Sales')
plt.show()

# 4. Count plot of 'Returned'
plt.figure(figsize=(8, 5))
sns.countplot(x='Returned', data=df)
plt.title('Count of Returned vs. Non-Returned Items')
plt.xlabel('Returned (0: No, 1: Yes)')
plt.ylabel('Count')
plt.xticks([0, 1], ['No', 'Yes'])
plt.show()

# %% [markdown]
# ## Prepare data for modeling

# %%
X = df.drop('Returned', axis=1)
y = df['Returned']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (140, 208)
# X_test shape: (60, 208)
# y_train shape: (140,)
# y_test shape: (60,)

# %% [markdown]
# ## Logistic regression

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score

df = pd.read_csv("/content/sample_data/Midterm_Retail_Sales.csv")
# Drop OrderID as it's not a predictive feature
df = df.drop('OrderID', axis=1)

# Handle categorical variables
categorical_cols = df.select_dtypes(include=['object']).columns
df = pd.get_dummies(df, columns=categorical_cols, drop_first=True)

X = df.drop(['Returned'], axis=1)
y = df['Returned']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

clf = LogisticRegression(max_iter=1000)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.8333333333333334
#               precision    recall  f1-score   support
#
#            0       0.83      1.00      0.91        50
#            1       0.00      0.00      0.00        10
#
#     accuracy                           0.83        60
#    macro avg       0.42      0.50      0.45        60
# weighted avg       0.69      0.83      0.76        60
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %% [markdown]
# ## Decision tree

# %%
from sklearn.tree import DecisionTreeClassifier

# Instantiate the Decision Tree Classifier
dt_clf = DecisionTreeClassifier(random_state=42)

# Fit the model to the training data
dt_clf.fit(X_train, y_train)

# Make predictions on the testing data
y_pred_dt = dt_clf.predict(X_test)

# Calculate and print the accuracy score
accuracy_dt = accuracy_score(y_test, y_pred_dt)
print("Decision Tree Accuracy:", accuracy_dt)

# Print the classification report
print("Decision Tree Classification Report:")
print(classification_report(y_test, y_pred_dt))
# Out:
# Decision Tree Accuracy: 0.8333333333333334
# Decision Tree Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.83      1.00      0.91        50
#            1       0.00      0.00      0.00        10
#
#     accuracy                           0.83        60
#    macro avg       0.42      0.50      0.45        60
# weighted avg       0.69      0.83      0.76        60
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %% [markdown]
# ## Compare models

# %%
print("Logistic Regression Accuracy:", accuracy_score(y_test, y_pred))
print("Logistic Regression Classification Report:")
print(classification_report(y_test, y_pred))

print("\nDecision Tree Accuracy:", accuracy_dt)
print("Decision Tree Classification Report:")
print(classification_report(y_test, y_pred_dt))

print("\n--- Model Comparison Summary ---")
print("Overall Accuracy:")
print(f"  Logistic Regression: {accuracy_score(y_test, y_pred):.2f}")
print(f"  Decision Tree: {accuracy_dt:.2f}")

print("\nPerformance on 'Returned' items (Class 1):")
print("  Logistic Regression:")
print("    Precision: 0.00 (Undefined)")
print("    Recall: 0.00")
print("    F1-score: 0.00")
print("  Decision Tree:")
# Extract metrics for class 1 from Decision Tree report
report_dt = classification_report(y_test, y_pred_dt, output_dict=True)
dt_precision_1 = report_dt['1']['precision']
dt_recall_1 = report_dt['1']['recall']
dt_f1_score_1 = report_dt['1']['f1-score']
print(f"    Precision: {dt_precision_1:.2f}")
print(f"    Recall: {dt_recall_1:.2f}")
print(f"    F1-score: {dt_f1_score_1:.2f}")

print("\nAnalysis:")
print("Both models achieved the same overall accuracy of 0.83.")
print("However, both models struggled to predict the 'Returned' class (class 1), which is the minority class.")
print("The Logistic Regression model did not predict any instances of class 1, resulting in 0 precision, recall, and f1-score for this class.")
print("The Decision Tree model also did not predict any instances of class 1, resulting in 0 precision, recall, and f1-score for this class.")
print("This suggests that the data is imbalanced, and neither model, in their current form, is effective at identifying returned items.")
print("Further steps to address class imbalance, such as resampling techniques or using different evaluation metrics (like AUC-ROC), would be necessary to improve the prediction of returned items.")
# Out:
# Logistic Regression Accuracy: 0.8333333333333334
# Logistic Regression Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.83      1.00      0.91        50
#            1       0.00      0.00      0.00        10
#
#     accuracy                           0.83        60
#    macro avg       0.42      0.50      0.45        60
# weighted avg       0.69      0.83      0.76        60
#
#
# Decision Tree Accuracy: 0.8333333333333334
# Decision Tree Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.83      1.00      0.91        50
#            1       0.00      0.00      0.00        10
#
#     accuracy                           0.83        60
#    macro avg       0.42      0.50      0.45        60
# weighted avg       0.69      0.83      0.76        60
#
#
# --- Model Comparison Summary ---
# Overall Accuracy:
#   Logistic Regression: 0.83
#   Decision Tree: 0.83
#
# ...
